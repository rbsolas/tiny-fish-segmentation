# %%
from ultralytics import YOLO

# %%
model_n = YOLO("yolo11n-seg.yaml").load("yolo11n-seg.pt")  # build from YAML and transfer weights
# Out:
# Transferred 561/561 items from pretrained weights

# %%
model_x = YOLO("yolo11x-seg.yaml").load("yolo11x-seg.pt")  # build from YAML and transfer weights
# Out:
# Transferred 1077/1077 items from pretrained weights

# %%
DATA_YAML = "/mnt/c/Users/Rohan/Desktop/projects/datasets/underwater-instance-segmentation-v3/data.yaml"

EPOCHS = 1
BATCH = 16
IMGSZ = 640
SAVE_PERIOD = 1
DEVICE = 0
PROJECT = "./"
NAME = DATA_YAML.split("/")[8] + f"_{EPOCHS}e_{BATCH}b"
SEED = 42

# %%
results = model_x.train(data=DATA_YAML, 
                        epochs=EPOCHS, 
                        batch=BATCH, 
                        imgsz=IMGSZ, 
                        save_period=SAVE_PERIOD,
                        device=DEVICE,
                        project=PROJECT,
                        name=NAME,
                        seed=SEED)
# Out:
# New https://pypi.org/project/ultralytics/8.3.70 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...
